# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52455/stat_mlassignments/blob/main/Sml_Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/train.csv')

# %%
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
y = data['price_range']
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
x=data.drop(['price_range'],axis=1)
x
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
nd = x-x.min()/x.max()-x.min()
nd
# Out:
#       battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0        340.749249   0.0     1.533333       0.0   1.0     0.0     4.96875
# 1        519.749249   1.0    -0.166667       1.0   0.0     1.0    50.96875
# 2         61.749249   1.0    -0.166667       1.0   2.0     1.0    38.96875
# 3        113.749249   1.0     1.833333       0.0   0.0     0.0     7.96875
# 4       1319.749249   1.0     0.533333       0.0  13.0     1.0    41.96875
# ...             ...   ...          ...       ...   ...     ...         ...
# 1995     292.749249   1.0    -0.166667       1.0   0.0     1.0    -0.03125
# 1996    1463.749249   1.0     1.933333       1.0   0.0     0.0    36.96875
# 1997    1409.749249   0.0     0.233333       1.0   1.0     1.0    33.96875
# 1998    1010.749249   0.0     0.233333       0.0   4.0     1.0    43.96875
# 1999       8.749249   1.0     1.333333       1.0   5.0     1.0    42.96875
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(nd,y,test_size=0.3,random_state=30)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1400, 20)
# (600, 20)
# (1400,)
# (600,)

# %% [markdown]
# # **Question 2**

# %%
data2 = pd.read_csv('/content/housing.csv')
data2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data2 = data2.fillna(0)

# %%
pop = data2['population']
lon = data2['longitude']
lat = data2['latitude']
med_house_val = data2['median_house_value']
med_income = data2['median_income']
hou_med_age = data2['housing_median_age']
total_rooms = data2['total_rooms']
total_bedrooms = data2['total_bedrooms']
households = data2['households']

# %%
print(pop.dtype)
print(lon.dtype)
print(lat.dtype)
print(med_house_val.dtype)
print(med_income.dtype)
print(hou_med_age.dtype)
print(total_rooms.dtype)
print(total_bedrooms.dtype)
print(households.dtype)
# Out:
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64

# %%
print(pop.shape)
print(lon.shape)
print(lat.shape)
print(med_house_val.shape)
print(med_income.shape)
print(hou_med_age.shape)
print(total_rooms.shape)
print(total_bedrooms.shape)
print(households.shape)
# Out:
# (20640,)
# (20640,)
# (20640,)
# (20640,)
# (20640,)
# (20640,)
# (20640,)
# (20640,)
# (20640,)

# %%
target = med_house_val
D = data2.drop(['median_house_value'],axis=1) #feature
D = data2.drop(['ocean_proximity'],axis=1)

# %%
NData = D-D.min()/(D.max()-D.min())
NData
# Out:
#         longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -109.844542  34.421977           40.980392   879.999949           129.0
# 1     -109.834542  34.401977           20.980392  7098.999949          1106.0
# 2     -109.854542  34.391977           51.980392  1466.999949           190.0
# 3     -109.864542  34.391977           51.980392  1273.999949           235.0
# 4     -109.864542  34.391977           51.980392  1626.999949           280.0
# ...           ...        ...                 ...          ...             ...
# 20635 -108.704542  36.021977           24.980392  1664.999949           374.0
# 20636 -108.824542  36.031977           17.980392   696.999949           150.0
# 20637 -108.834542  35.971977           16.980392  2253.999949           485.0
# 20638 -108.934542  35.971977           17.980392  1859.999949           409.0
# 20639 -108.854542  35.911977           15.980392  2784.999949           616.0
#
# ...

# %%
D_train, D_test, target_train, target_test = train_test_split(NData,target,test_size=0.3,random_state=30)
print(D_train.shape)
print(D_test.shape)
print(target_train.shape)
print(target_test.shape)
# Out:
# (14448, 9)
# (6192, 9)
# (14448,)
# (6192,)
